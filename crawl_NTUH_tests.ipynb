# %%
import requests
import pandas as pd
from time import sleep
from lxml import etree, html

# %%
url = "https://www.ntuh.gov.tw/labmed/檢驗目錄/Lists/2015/AllItems.aspx"

tests = dict(test_ename = [], test_cname = [], specimen = [], reference_range = [], detail_link = [])
# Get the source code of the html
result = ""
while result == "":
    try:
        # Certificate is not verified to bypass the SSLError
        # Not secure though
        result = requests.get(url, verify = False)
        break
    except:
        sleep(5)
        continue
# Transform it into an element tree
root = etree.fromstring(result.content, etree.HTMLParser())
# Parse the information with Xpath
for row in root.xpath("//table[@class='ms-listviewtable']/tr"):
    tests["test_ename"].append(row.xpath("./td/div/a/text()")[0].strip())
    tests["test_cname"].append(row.xpath("./td/text()")[0].strip())
    try:
        tests["specimen"].append(row.xpath("./td/div/font/text()")[0].strip())
    except IndexError:
        tests["specimen"].append(row.xpath("./td/div/div/text()")[0].strip())
    tests["reference_range"].append("\n".join(map(lambda x: x.strip(),row.xpath("./td/div/font/text()")[1:])))
    tests["detail_link"].append(row.xpath("./td/div/a/@href")[0].strip())
# Out:
# /Users/tuyuzhen/miniconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
pd.DataFrame(tests)[["test_ename", "test_cname", "specimen", "reference_range", "detail_link"]]
# Out:
#                                            test_ename  \
# 0                                  (Iron & TIBC)_Iron
# 1                                  (Iron & TIBC)_TIBC
# 2                                       17-KS (Urine)
# 3                                     25-OH Vitamin D
# 4                                             3P Test
# 5                                    5-Fluorocytosine
# 6                  Abdominal mass aspiration cytology
# 7                             Abdomonal mass  imprint
# 8                                          ABO Typing
# 9                                 Acetaminophen(STAT)
# 10  Acid fast stain & Mycobacterium culture (Aspir...
# 11  Acid fast stain & Mycobacterium culture(Biopsy...
# 12  Acid fast stain & Mycobacterium culture(Body f...
# 13  Acid fast stain & Mycobacterium culture(Drain ...
# 14  Acid fast stain & Mycobacterium culture(Drainage)
# 15  Acid fast stain & Mycobacterium culture(Intrav...
# 16    Acid fast stain & Mycobacterium culture(Others)
# 17  Acid fast stain & Mycobacterium culture(Pus-di...
# 18  Acid fast stain & Mycobacterium culture(Respir...
# 19                           Adenosine Deaminase, ADA
# 20                   Adenosine Deaminase, ADA_CSF,PLE
# 21                                Adenovirus 40/41 Ag
# 22                   Adrenocorticotropic hormone,ACTH
# 23  Aerobic & anaerobic  pathogen culture (Aspirat...
# 24  Aerobic & anaerobic  pathogen culture (Biopsy&...
# 25  Aerobic & anaerobic  pathogen culture (Body fl...
# 26  Aerobic & anaerobic  pathogen culture (Intrava...
# 27  Aerobic & anaerobic  pathogen culture (Pus-dis...
# 28  Aerobic & anaerobic  pathogen culture(Drain tube)
# 29    Aerobic & anaerobic  pathogen culture(Drainage)
# 30                            AFP＋β-HCG＋uE3＋Inhibin A
# 31                                     Albumin(Blood)
# 32                               Albumin(Blood)(STAT)
# 33                                       Albumin(CSF)
# 34                    Albumin/Globulin Ratio(Alb/Glo)
# 35                                                ALP
# 36                                          ALP(STAT)
# 37                                Alpha-1-antitrypsin
# 38                                 Alpha2-antiplasmin
# 39                             Alpha-FetoProtein(AFP)
# 40                                           ALT(GPT)
# 41                                     ALT(GPT)(STAT)
# 42                                       Aluminum(Al)
# 43                                           Amikacin
# 44                                      Ammonia(STAT)
# 45                                             Amoeba
# 46                 Amoebic hemagglutination test(IHA)
# 47                                     Amphotericin B
# 48                                            Amylase
# 49                                      Amylase(STAT)
#
#                     test_cname  \
# 0                          血清鐵
# 1                       總鐵結合能力
# 2                  尿液17-酮類固醇定量
# 3                         維生素D
# 4                  硫酸魚精蛋白副凝固試驗
# 5   抗黴菌藥物5-Fluorocytosine敏感性試驗
# 6                腹部腫瘤細針穿刺細胞學檢查
# 7                腹部腫塊捺印抹片細胞學檢查
# 8                         血型測定
# 9        鎮痛解熱藥物Acetaminophen濃度
# 10             分枝桿菌培養 （含抗酸性染色）
# 11             分枝桿菌培養 （含抗酸性染色）
# 12             分枝桿菌培養 （含抗酸性染色）
# 13             分枝桿菌培養 （含抗酸性染色）
# 14             分枝桿菌培養 （含抗酸性染色）
# 15             分枝桿菌培養 （含抗酸性染色）
# 16             分枝桿菌培養 （含抗酸性染色）
# 17             分枝桿菌培養 （含抗酸性染色）
# 18             分枝桿菌培養 （含抗酸性染色）
# 19                      腺核苷去胺酶
# 20                      腺核苷去胺酶
# 21                 腺病毒40/41型抗原
# 22                     腎上腺皮質激素
# 23                  一般嗜氧與厭氧菌培養
# 24                  一般嗜氧與厭氧菌培養
# 25                  一般嗜氧與厭氧菌培養
# 26                  一般嗜氧與厭氧菌培養
# 27                  一般嗜氧與厭氧菌培養
# 28                  一般嗜氧與厭氧菌培養
# 29                  一般嗜氧與厭氧菌培養
# 30            懷孕第二期唐氏症篩檢（試劑檢驗）
# 31                         白蛋白
# 32                         白蛋白
# 33                    白蛋白(CSF)
# 34                   白蛋白/球蛋白比值
# 35                      鹼性磷酸酵素
# 36                      鹼性磷酸酵素
# 37             Alpha1胰蛋白脢抑制脢定量
# 38            Alpha2纖維蛋白溶解素抑制劑
# 39                   Alpha胎兒蛋白
# 40                     丙胺酸轉胺酵素
# 41                     丙胺酸轉胺酵素
# 42                           鋁
# 43           血中抗生素Amikacin藥物濃度
# 44                           氨
# 45                     阿米巴原蟲檢測
# 46                 間接阿米巴血液凝集試驗
# 47    抗黴菌藥物Amphotericin B敏感性試驗
# 48                        澱粉酵素
# 49                        澱粉酵素
#
#                                              specimen  \
# 0                                           血清(Serum)
# 1                                           血清(Serum)
# 2                                二十四小時尿液(24hrs Urine)
# 3                                           血清(Serum)
# 4                           血漿(Sodium citrate Plasma)
# 5                                                  菌種
# 6          腹部腫瘤細針穿刺抹片或穿刺液體(Abdominal mass aspiration)
# 7                   腹部腫塊捺印抹片(Abdomonal mass  imprint)
# 8                                全血(EDTA Whole Blood)
# 9                                           血清(Serum)
# 10                        膿腫(Abscess)、淋巴結(Lymph node)
# 11                                         組織(Tissue)
# 12  腦脊髓液(CSF)、胸水(Pleural effusion)、腹水(Ascites)、體液(...
# 13                                    引流管(Drain tube)
# 14                                      引流液(Drainage)
# 15                                                 導管
# 16                      血液(Blood)、糞便(Stool)、尿液(Urine)
# 17  外科傷口(Surgical wound)、褥瘡(Bed sore)、燒傷(Burn) 、眼睛...
# 18                                 痰液 (Sputum)、支氣管取出物
# 19                                          血清(Serum)
# 20                     胸水(Pleural effusion)；腦脊髓液(CSF)
# 21                                          糞便(stool)
# 22                                    血漿(EDTA Plasma)
# 23                                        膿腫(Abscess)
# 24                                         組織(Tissue)
# 25  腦脊髓液(CSF)、胸水(Pleural effusion)、腹水(Ascites)、體液(...
# 26                                                 導管
# 27  外科傷口(Surgical wound)、褥瘡(Bed sore)、燒傷(Burn) 、眼睛...
# 28                                    引流管(Drain tube)
# 29                        引流液(Drainage)、透析液(Dialysis)
# 30                                          血清(Serum)
# 31                                          血清(Serum)
# 32                                 血漿(Heparin Plasma)
# 33                                          腦脊髓液(CSF)
# 34                                          血清(Serum)
# 35                                          血清(Serum)
# 36                                 血漿(Heparin Plasma)
# 37                                          血清(Serum)
# 38                          血漿(Sodium citrate Plasma)
# 39                                          血清(Serum)
# 40                                          血清(Serum)
# 41                                 血漿(Heparin Plasma)
# 42                                          血清(Serum)
# 43                                          血清(Serum)
# 44                                 血漿(Heparin Plasma)
# 45                                          糞便(stool)
# 46                                          血清(Serum)
# 47                                                 菌種
# 48                                          血清(Serum)
# 49                                 血漿(Heparin Plasma)
#
#                                       reference_range  \
# 0   51~209 µg/dL (2013/11/13變更)\n(2012/07/05～2013/...
# 1   268~593 µg/dL (2013/11/13變更，舊參考值為 275 - 332 µg...
# 2                ♂：6 - 22 mg/24hrs\n♀：4 - 16 mg/24hrs
# 3
# 4                                            Negative
# 5                                            不適用(N/A)
# 6                                            不適用(N/A)
# 7                                            不適用(N/A)
# 8
# 9                              有效治療濃度範圍：10 ~ 30 µg/mL
# 10                        Stain negative &\nNo growth
# 11                        Stain negative &\nNo growth
# 12                        Stain negative &\nNo growth
# 13                        Stain negative &\nNo growth
# 14                        Stain negative &\nNo growth
# 15                        Stain negative &\nNo growth
# 16
# 17                        Stain negative &\nNo growth
# 18
# 19
# 20
# 21
# 22  7.40 ~ 57.30 pg/mL (2013/11/13變更，舊參考值為 10 ~ 65...
# 23                                          No growth
# 24                                          No growth
# 25                                          No growth
# 26                                          No growth
# 27                                          No growth
# 28                                          No growth
# 29                                          No growth
# 30                                           不適用(N/A)
# 31      3.5~5.7 g/dL (2013/11/13變更，舊參考值為3.5~5.0 g/dL)
# 32
# 33                                  13.4 ~ 23.7 mg/dL
# 34  Globulin：1.8~4.0 g/dL\nAlbumin/Globulin Ratio(...
# 35    34 ~ 104 U/L\n(2012/01/02 起變更，舊參考值為 60~220 U/L)
# 36
# 37   84~218 mg/dL (2013/11/13變更，舊參考值為 97 - 161 mg/dL)
# 38           74.5~135.2% (2013/11/13變更，舊參考值為 80-120%)
# 39                                         < 20 ng/mL
# 40  0~41 U/L (2013/11/13變更，舊參考值為♂：< 41 U/L；♀：< 31 ...
# 41
# 42
# 43             有效治療濃度範圍：\npeak：20~30 µg/mL\ntrough：\n
# 44
# 45                                          not found
# 46                                           < 1 : 32
# 47                                           不適用(N/A)
# 48           29~103 U/L(2012/01/02起變更，舊參考值:< 220 U/L)
# 49
#
#                                           detail_link
# 0   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 1   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 2   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 3   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 4   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 5   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 6   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 7   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 8   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 9   https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 10  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 11  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 12  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 13  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 14  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 15  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 16  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 17  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 18  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 19  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 20  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 21  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 22  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 23  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 24  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 25  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 26  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 27  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 28  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 29  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 30  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 31  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 32  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 33  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 34  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 35  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 36  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 37  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 38  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 39  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 40  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 41  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 42  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 43  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 44  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 45  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 46  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 47  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 48  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
# 49  https://www.ntuh.gov.tw/labmed/檢驗目錄/_layouts/1...
